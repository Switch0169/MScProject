# %%
import json
import re
from tqdm import tqdm
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\15710\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\15710\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\15710\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Data Loading
#
# Load squad data from json

# %%
lemmatizer = WordNetLemmatizer()

# %%
def load_squad_data(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data['data']

# %% [markdown]
# ## Data cleaning

# %%
def clean_text(text):
    # Remove special characters and digits
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert to lowercase
    text = text.lower()
    return text

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

def lemmatize_text(text):
    words = word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# %%
def preprocess_squad(data):
    processed_data = []
    
    for article in tqdm(data, desc="Processing articles"):
        for paragraph in article['paragraphs']:
            context = paragraph['context']
            
            # Clean and preprocess context
            cleaned_context = clean_text(context)
            cleaned_context = remove_stopwords(cleaned_context)
            # cleaned_context = lemmatize_text(cleaned_context)
            
            for qa in paragraph['qas']:
                question = qa['question']
                
                # Clean and preprocess question
                cleaned_question = clean_text(question)
                cleaned_question = remove_stopwords(cleaned_question)
                # cleaned_question = lemmatize_text(cleaned_question)
                
                # Handle answers
                if qa['is_impossible']:
                    answer_text = ''
                    answer_start = -1
                else:
                    answer = qa['answers'][0]  # Consider only the first answer
                    answer_text = answer['text']
                    answer_start = answer['answer_start']
                
                processed_data.append({
                    'id': qa['id'],
                    'context': cleaned_context,
                    'question': cleaned_question,
                    'answer_text': answer_text,
                    'answer_start': answer_start,
                    'is_impossible': qa['is_impossible']
                })
    
    return processed_data

# %%
train_data = load_squad_data("./dev-v2.0.json")

# %%
processed_train_data = preprocess_squad(train_data)
# Out:
# Processing articles: 100%|██████████| 35/35 [00:05<00:00,  5.92it/s]

# %%
processed_train_data
# Out:
# [{'id': '56ddde6b9a695914005b9628',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'country normandy located',
#   'answer_text': 'France',
#   'answer_start': 159,
#   'is_impossible': False},
#  {'id': '56ddde6b9a695914005b9629',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'normans normandy',
#   'answer_text': '10th and 11th centuries',
#   'answer_start': 94,
#   'is_impossible': False},
#  {'id': '56ddde6b9a695914005b962a',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'countries norse originate',
#   'answer_text': 'Denmark, Iceland and Norway',
#   'answer_start': 256,
#   'is_impossible': False},
#  {'id': '56ddde6b9a695914005b962b',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'norse leader',
#   'answer_text': 'Rollo',
#   'answer_start': 308,
#   'is_impossible': False},
#  {'id': '56ddde6b9a695914005b962c',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'century normans first gain separate identity',
#   'answer_text': '10th century',
#   'answer_start': 671,
#   'is_impossible': False},
#  {'id': '5ad39d53604f3c001a3fe8d1',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'gave name normandy',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad39d53604f3c001a3fe8d2',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'france region',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad39d53604f3c001a3fe8d3',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'king charles iii swear fealty',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad39d53604f3c001a3fe8d4',
#   'context': 'normans norman nourmands french normands latin normanni people th th centuries gave name normandy region france descended norse norman comes norseman raiders pirates denmark iceland norway leader rollo agreed swear fealty king charles iii west francia generations assimilation mixing native frankish romangaulish populations descendants would gradually merge carolingianbased cultures west francia distinct cultural ethnic identity normans emerged initially first half th century continued evolve succeeding centuries',
#   'question': 'frankish identity emerge',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dddf4066d3e219004dad5f',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'duke battle hastings',
#   'answer_text': 'William the Conqueror',
#   'answer_start': 1022,
#   'is_impossible': False},
#  {'id': '56dddf4066d3e219004dad60',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'ruled duchy normandy',
#   'answer_text': 'Richard I',
#   'answer_start': 573,
#   'is_impossible': False},
#  {'id': '56dddf4066d3e219004dad61',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'religion normans',
#   'answer_text': 'Catholic',
#   'answer_start': 230,
#   'is_impossible': False},
#  {'id': '5ad3a266604f3c001a3fea27',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'type major impact norman dynasty modern europe',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3a266604f3c001a3fea28',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'famed christian spirit',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3a266604f3c001a3fea29',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'assimilted roman language',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3a266604f3c001a3fea2a',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'ruled country normandy',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3a266604f3c001a3fea2b',
#   'context': 'norman dynasty major political cultural military impact medieval europe even near east normans famed martial spirit eventually christian piety becoming exponents catholic orthodoxy assimilated adopted galloromance language frankish land settled dialect becoming known norman normaund norman french important literary language duchy normandy formed treaty french crown great fief medieval france richard normandy forged cohesive formidable principality feudal tenure normans noted culture unique romanesque architecture musical traditions significant military accomplishments innovations norman adventurers founded kingdom sicily roger ii conquering southern italy saracens byzantines expedition behalf duke william conqueror led norman conquest england battle hastings norman cultural military influence spread new european centres crusader states near east prince bohemond founded principality antioch levant scotland wales great britain ireland coasts north africa canary islands',
#   'question': 'principality william conquerer found',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dde0379a695914005b9636',
#   'context': 'english name normans comes french words normansnormanz plural normant modern french normand borrowed old low franconian nortmann northman directly old norse normar latinized variously nortmannus normannus nordmannus recorded medieval latin th century mean norseman viking',
#   'question': 'original meaning word norman',
#   'answer_text': 'Viking',
#   'answer_start': 341,
#   'is_impossible': False},
#  {'id': '56dde0379a695914005b9637',
#   'context': 'english name normans comes french words normansnormanz plural normant modern french normand borrowed old low franconian nortmann northman directly old norse normar latinized variously nortmannus normannus nordmannus recorded medieval latin th century mean norseman viking',
#   'question': 'latin version word norman first recorded',
#   'answer_text': '9th century',
#   'answer_start': 309,
#   'is_impossible': False},
#  {'id': '5ad3ab70604f3c001a3feb89',
#   'context': 'english name normans comes french words normansnormanz plural normant modern french normand borrowed old low franconian nortmann northman directly old norse normar latinized variously nortmannus normannus nordmannus recorded medieval latin th century mean norseman viking',
#   'question': 'name comes english words normansnormanz',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ab70604f3c001a3feb8a',
#   'context': 'english name normans comes french words normansnormanz plural normant modern french normand borrowed old low franconian nortmann northman directly old norse normar latinized variously nortmannus normannus nordmannus recorded medieval latin th century mean norseman viking',
#   'question': 'french version word norman first recorded',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dde0ba66d3e219004dad75',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'duchy normandy founded',
#   'answer_text': '911',
#   'answer_start': 244,
#   'is_impossible': False},
#  {'id': '56dde0ba66d3e219004dad76',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'rollo sign treaty saintclairsurepte',
#   'answer_text': 'King Charles III',
#   'answer_start': 324,
#   'is_impossible': False},
#  {'id': '56dde0ba66d3e219004dad77',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'river originally bounded duchy',
#   'answer_text': 'Seine',
#   'answer_start': 711,
#   'is_impossible': False},
#  {'id': '5ad3ad61604f3c001a3fec0d',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'nors encampments ivolve destructive incursions',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ad61604f3c001a3fec0e',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'treaty established th century',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ad61604f3c001a3fec0f',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'established treaty king charles third france',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ad61604f3c001a3fec10',
#   'context': 'course th century initially destructive incursions norse war bands rivers france evolved permanent encampments included local women personal property duchy normandy began fiefdom established treaty saintclairsurepte king charles iii west francia famed viking ruler rollo situated former frankish kingdom neustria treaty offered rollo men french lands river epte atlantic coast exchange protection viking incursions area corresponded northern part presentday upper normandy river seine duchy would eventually extend west beyond seine territory roughly equivalent old province rouen reproduced roman administrative structure gallia lugdunensis ii part former gallia lugdunensis',
#   'question': 'french promises protect rollo men',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dde1d966d3e219004dad8d',
#   'context': 'rollos arrival populations differ picardy ledefrance considered frankish earlier viking settlers begun arriving divided colonies east roumois pays de caux around low seine valley west cotentin peninsula separated traditional pagii population remained almost foreign settlers rollos contingents raided ultimately settled normandy parts atlantic coast included danes norwegians norsegaels orkney vikings possibly swedes anglodanes english danelaw norse control',
#   'question': 'upon arriving gave original viking settlers common identity',
#   'answer_text': 'Rollo',
#   'answer_start': 7,
#   'is_impossible': False},
#  {'id': '5ad3ae14604f3c001a3fec39',
#   'context': 'rollos arrival populations differ picardy ledefrance considered frankish earlier viking settlers begun arriving divided colonies east roumois pays de caux around low seine valley west cotentin peninsula separated traditional pagii population remained almost foreign settlers rollos contingents raided ultimately settled normandy parts atlantic coast included danes norwegians norsegaels orkney vikings possibly swedes anglodanes english danelaw norse control',
#   'question': 'rollo begin arrive normandy',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ae14604f3c001a3fec3a',
#   'context': 'rollos arrival populations differ picardy ledefrance considered frankish earlier viking settlers begun arriving divided colonies east roumois pays de caux around low seine valley west cotentin peninsula separated traditional pagii population remained almost foreign settlers rollos contingents raided ultimately settled normandy parts atlantic coast included danes norwegians norsegaels orkney vikings possibly swedes anglodanes english danelaw norse control',
#   'question': 'viking groups conquered rollo',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dde27d9a695914005b9651',
#   'context': 'descendants rollos vikings frankish wives would replace norse religion old norse language catholicism christianity galloromance language local people blending maternal frankish heritage old norse traditions customs synthesize unique norman culture north france norman language forged adoption indigenous langue dol branch romance norsespeaking ruling class developed regional language survives today',
#   'question': 'norman religion',
#   'answer_text': 'Catholicism',
#   'answer_start': 121,
#   'is_impossible': False},
#  {'id': '56dde27d9a695914005b9652',
#   'context': 'descendants rollos vikings frankish wives would replace norse religion old norse language catholicism christianity galloromance language local people blending maternal frankish heritage old norse traditions customs synthesize unique norman culture north france norman language forged adoption indigenous langue dol branch romance norsespeaking ruling class developed regional language survives today',
#   'question': 'part france normans located',
#   'answer_text': 'north',
#   'answer_start': 327,
#   'is_impossible': False},
#  {'id': '5ad3af11604f3c001a3fec63',
#   'context': 'descendants rollos vikings frankish wives would replace norse religion old norse language catholicism christianity galloromance language local people blending maternal frankish heritage old norse traditions customs synthesize unique norman culture north france norman language forged adoption indigenous langue dol branch romance norsespeaking ruling class developed regional language survives today',
#   'question': 'replace norse religion',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3af11604f3c001a3fec64',
#   'context': 'descendants rollos vikings frankish wives would replace norse religion old norse language catholicism christianity galloromance language local people blending maternal frankish heritage old norse traditions customs synthesize unique norman culture north france norman language forged adoption indigenous langue dol branch romance norsespeaking ruling class developed regional language survives today',
#   'question': 'maternal old norse traditions merge',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3af11604f3c001a3fec65',
#   'context': 'descendants rollos vikings frankish wives would replace norse religion old norse language catholicism christianity galloromance language local people blending maternal frankish heritage old norse traditions customs synthesize unique norman culture north france norman language forged adoption indigenous langue dol branch romance norsespeaking ruling class developed regional language survives today',
#   'question': 'language replaced galloromance language',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56dde2fa66d3e219004dad9b',
#   'context': 'normans thereafter adopted growing feudal doctrines rest france worked functional hierarchical system normandy england new norman rulers culturally ethnically distinct old french aristocracy traced lineage franks carolingian dynasty norman knights remained poor landhungry normandy exporting fighting horsemen generation many normans italy france england eventually served avid crusaders italonorman prince bohemund anglonorman king richard lionheart',
#   'question': 'one normans major exports',
#   'answer_text': 'fighting horsemen',
#   'answer_start': 428,
#   'is_impossible': False},
#  {'id': '5ad3c626604f3c001a3ff011',
#   'context': 'normans thereafter adopted growing feudal doctrines rest france worked functional hierarchical system normandy england new norman rulers culturally ethnically distinct old french aristocracy traced lineage franks carolingian dynasty norman knights remained poor landhungry normandy exporting fighting horsemen generation many normans italy france england eventually served avid crusaders italonorman prince bohemund anglonorman king richard lionheart',
#   'question': 'adopted fuedel doctrines normans',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3c626604f3c001a3ff012',
#   'context': 'normans thereafter adopted growing feudal doctrines rest france worked functional hierarchical system normandy england new norman rulers culturally ethnically distinct old french aristocracy traced lineage franks carolingian dynasty norman knights remained poor landhungry normandy exporting fighting horsemen generation many normans italy france england eventually served avid crusaders italonorman prince bohemund anglonorman king richard lionheart',
#   'question': 'one normans major imports',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3c626604f3c001a3ff013',
#   'context': 'normans thereafter adopted growing feudal doctrines rest france worked functional hierarchical system normandy england new norman rulers culturally ethnically distinct old french aristocracy traced lineage franks carolingian dynasty norman knights remained poor landhungry normandy exporting fighting horsemen generation many normans italy france england eventually served avid crusaders italonorman prince bohemund anglonorman king richard lionheart',
#   'question': 'whos arristocracy eventually served avid crusaders',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56de0f6a4396321400ee257f',
#   'context': 'soon normans began enter italy entered byzantine empire armenia fighting pechenegs bulgars especially seljuk turks norman mercenaries first encouraged come south lombards act byzantines soon fought byzantine service sicily prominent alongside varangian lombard contingents sicilian campaign george maniaces debate whether normans greek service actually norman italy seems likely came also unknown many franks byzantines called normans frenchmen',
#   'question': 'normans main enemy italy byzantine empire armenia',
#   'answer_text': 'Seljuk Turks',
#   'answer_start': 161,
#   'is_impossible': False},
#  {'id': '5ad3dbc6604f3c001a3ff3e9',
#   'context': 'soon normans began enter italy entered byzantine empire armenia fighting pechenegs bulgars especially seljuk turks norman mercenaries first encouraged come south lombards act byzantines soon fought byzantine service sicily prominent alongside varangian lombard contingents sicilian campaign george maniaces debate whether normans greek service actually norman italy seems likely came also unknown many franks byzantines called normans frenchmen',
#   'question': 'entered italy soon byzantine empire',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3dbc6604f3c001a3ff3ea',
#   'context': 'soon normans began enter italy entered byzantine empire armenia fighting pechenegs bulgars especially seljuk turks norman mercenaries first encouraged come south lombards act byzantines soon fought byzantine service sicily prominent alongside varangian lombard contingents sicilian campaign george maniaces debate whether normans greek service actually norman italy seems likely came also unknown many franks byzantines called normans frenchmen',
#   'question': 'normans fight italy',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3dbc6604f3c001a3ff3eb',
#   'context': 'soon normans began enter italy entered byzantine empire armenia fighting pechenegs bulgars especially seljuk turks norman mercenaries first encouraged come south lombards act byzantines soon fought byzantine service sicily prominent alongside varangian lombard contingents sicilian campaign george maniaces debate whether normans greek service actually norman italy seems likely came also unknown many franks byzantines called normans frenchmen',
#   'question': 'normans encourage come south',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3dbc6604f3c001a3ff3ec',
#   'context': 'soon normans began enter italy entered byzantine empire armenia fighting pechenegs bulgars especially seljuk turks norman mercenaries first encouraged come south lombards act byzantines soon fought byzantine service sicily prominent alongside varangian lombard contingents sicilian campaign george maniaces debate whether normans greek service actually norman italy seems likely came also unknown many franks byzantines called normans frenchmen',
#   'question': 'campaign vargian lombard fight',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56de0ffd4396321400ee258d',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'herve serve byzantine general',
#   'answer_text': '1050s',
#   'answer_start': 85,
#   'is_impossible': False},
#  {'id': '56de0ffd4396321400ee258e',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'robert crispin go turks',
#   'answer_text': '1060s',
#   'answer_start': 292,
#   'is_impossible': False},
#  {'id': '56de0ffd4396321400ee258f',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'ruined roussel de bailleuls plans independent state',
#   'answer_text': 'Alexius Komnenos',
#   'answer_start': 522,
#   'is_impossible': False},
#  {'id': '5ad3de8b604f3c001a3ff467',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'first byzantine mercenary serve normans',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3de8b604f3c001a3ff468',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'herve serve norman general',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3de8b604f3c001a3ff469',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'ruined alexius komnenos plans independent state',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3de8b604f3c001a3ff46a',
#   'context': 'one first norman mercenaries serve byzantine general herv however already norman mercenaries serving far away trebizond georgia based malatya edessa byzantine duke antioch isaac komnenos robert crispin led normans edessa turks roussel de bailleul even tried carve independent state asia minor support local population stopped byzantine general alexius komnenos',
#   'question': 'herve go turks',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56de10b44396321400ee2593',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'name norman castle',
#   'answer_text': 'Afranji',
#   'answer_start': 539,
#   'is_impossible': False},
#  {'id': '56de10b44396321400ee2594',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'leader franks entered euphrates valley',
#   'answer_text': 'Oursel',
#   'answer_start': 256,
#   'is_impossible': False},
#  {'id': '56de10b44396321400ee2595',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'normans team anatolia',
#   'answer_text': 'Turkish forces',
#   'answer_start': 20,
#   'is_impossible': False},
#  {'id': '5ad3e96b604f3c001a3ff689',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'joined norman forces destruction armenians',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3e96b604f3c001a3ff68a',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'turks take service',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3e96b604f3c001a3ff68b',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'frank led norman forces',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3e96b604f3c001a3ff68c',
#   'context': 'normans joined turkish forces aid destruction armenians vassalstates sassoun taron far eastern anatolia later many took service armenian state south cilicia taurus mountains norman named oursel led force franks upper euphrates valley northern syria troops armenian general philaretus brachamius normansformerly ourselled raimbaud even lent ethnicity name castle afranji meaning franks known trade amalfi antioch bari tarsus may related presence italonormans cities amalfi bari norman rule italy',
#   'question': 'oursel lead franks',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56de11154396321400ee25aa',
#   'context': 'several families byzantine greece norman mercenary origin period comnenian restoration byzantine emperors seeking western european warriors raoulii descended italonorman named raoul petraliphae descended pierre daulps group albanian clans known maniakates descended normans served george maniaces sicilian expedition',
#   'question': 'origins raouliii family',
#   'answer_text': 'Norman mercenary',
#   'answer_start': 45,
#   'is_impossible': False},
#  {'id': '5ad3ea79604f3c001a3ff6e9',
#   'context': 'several families byzantine greece norman mercenary origin period comnenian restoration byzantine emperors seeking western european warriors raoulii descended italonorman named raoul petraliphae descended pierre daulps group albanian clans known maniakates descended normans served george maniaces sicilian expedition',
#   'question': 'several norman mercenary familes originate',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ea79604f3c001a3ff6ea',
#   'context': 'several families byzantine greece norman mercenary origin period comnenian restoration byzantine emperors seeking western european warriors raoulii descended italonorman named raoul petraliphae descended pierre daulps group albanian clans known maniakates descended normans served george maniaces sicilian expedition',
#   'question': 'normans serve th century',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5ad3ea79604f3c001a3ff6eb',
#   'context': 'several families byzantine greece norman mercenary origin period comnenian restoration byzantine emperors seeking western european warriors raoulii descended italonorman named raoul petraliphae descended pierre daulps group albanian clans known maniakates descended normans served george maniaces sicilian expedition',
#   'question': 'expedition george maniaces lead th century',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '56de148dcffd8e1900b4b5bc',
#   'context': 'robert guiscard norman adventurer previously elevated dignity count apulia result military successes ultimately drove byzantines southern italy obtained consent pope gregory vii acting vassal robert continued campaign conquering balkan peninsula foothold western feudal lords catholic church allying croatia catholic cities dalmatia led army men ships landing southern shores albania capturing valona kanina jericho orikumi reaching butrint numerous pillages joined fleet previously conquered corfu attacked dyrrachium land sea devastating everything along way harsh circumstances locals accepted call emperor alexius comnenus join forces byzantines normans albanian forces could take part ensuing battle started arrival immediately battle venetian fleet secured victory coast surrounding city forced retreat alexius ceded command high albanian official named comiscortes service byzantium citys garrison resisted february dyrrachium betrayed normans venetian amalfitan merchants settled normans free penetrate hinterland took ioannina minor cities southwestern macedonia thessaly appearing gates thessalonica dissension among high ranks coerced normans retreat italy lost dyrrachium valona butrint death robert',
#   'question': 'name count apulia',
#   'answer_text': 'Robert Guiscard',
#   'answer_start': 0,
#   'is_impossible': False},
#  {'id': '56de148dcffd8e1900b4b5bd',
#   'context': 'robert guiscard norman adventurer previously elevated dignity count apulia result military successes ultimately drove byzantines southern italy obtained consent pope gregory vii acting vassal robert continued campaign conquering balkan peninsula foothold western feudal lords catholic church allying croatia catholic cities dalmatia led army men ships landing southern shores albania capturing valona kanina jericho orikumi reaching butrint numerous pillages joined fleet previously conquered corfu attacked dyrrachium land sea devastating everything along way harsh circumstances locals accepted call emperor alexius comnenus join forces byzantines normans albanian forces could take part ensuing battle started arrival immediately battle venetian fleet secured victory coast surrounding city forced retreat alexius ceded command high albanian official named comiscortes service byzantium citys garrison resisted february dyrrachium betrayed normans venetian amalfitan merchants settled normans free penetrate hinterland took ioannina minor cities southwestern macedonia thessaly appearing gates thessalonica dissension among high ranks coerced normans retreat italy lost dyrrachium valona butrint death robert',
#   'question': 'dyrrachium fall normans',
#   'answer_text': '1082',
#   'answer_start': 1315,
#   'is_impossible': False},
#  {'id': '56de148dcffd8e1900b4b5be',
#   'context': 'robert guiscard norman adventurer previously elevated dignity count apulia result military successes ultimately drove byzantines southern italy obtained consent pope gregory vii acting vassal robert continued campaign conquering balkan peninsula foothold western feudal lords catholic church allying croatia catholic cities dalmatia led army men ships landing southern shores albania capturing valona kanina jericho orikumi reaching butrint numerous pillages joined fleet previously conquered corfu attacked dyrrachium land sea devastating everything along way harsh circumstances locals accepted call emperor alexius comnenus join forces byzantines normans albanian forces could take part ensuing battle started arrival immediately battle venetian fleet secured victory coast surrounding city forced retreat alexius ceded command high albanian official named comiscortes service byzantium citys garrison resisted february dyrrachium betrayed normans venetian amalfitan merchants settled normans free penetrate hinterland took ioannina minor cities southwestern macedonia thessaly appearing gates thessalonica dissension among high ranks coerced normans retreat italy lost dyrrachium valona butrint death robert',
# ...
#   'question': 'bskyb team part consortium',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c14b4bfd06b001a5ae9d7',
#   'context': 'bskyb excluded part ondigital consortium thereby making competitor default bskyb able join itv digitals freetoair replacement freeview holds equal stake bbc itv channel national grid wireless prior october three bskyb channels available platform sky news sky three sky sports news initially bskyb provided sky travel service however replaced sky three october later rebranded pick tv',
#   'question': 'channel never rebranded',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '57094ca7efce8f15003a7dd6',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'service bskyb chare additional subscription fees',
#   'answer_text': 'Sky+ PVR',
#   'answer_start': 65,
#   'is_impossible': False},
#  {'id': '57094ca7efce8f15003a7dd7',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'sky launch tv advertising campaign target towards women',
#   'answer_text': 'September 2007',
#   'answer_start': 801,
#   'is_impossible': False},
#  {'id': '57094ca7efce8f15003a7dd8',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'allows customers get sky functions subscribe bskybs channels',
#   'answer_text': 'monthly fee',
#   'answer_start': 403,
#   'is_impossible': False},
#  {'id': '57094ca7efce8f15003a7dd9',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'bskyb discontinue sky box',
#   'answer_text': 'January 2010',
#   'answer_start': 444,
#   'is_impossible': False},
#  {'id': '57094ca7efce8f15003a7dda',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'replaced skybox',
#   'answer_text': 'Sky+HD Box',
#   'answer_start': 570,
#   'is_impossible': False},
#  {'id': '5a2c16e3bfd06b001a5ae9e7',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'service bskyb give away free unconditionally',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c16e3bfd06b001a5ae9e8',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'sky launch tv advertising campaign target towards men',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c16e3bfd06b001a5ae9e9',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'isnt required customers get sky functions subscribe bskybs channels',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c16e3bfd06b001a5ae9ea',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'bskyb upgrade sky box',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c16e3bfd06b001a5ae9eb',
#   'context': 'bskyb initially charged additional subscription fees using sky pvr service waiving charge subscribers whose package included two premium channels changed july customers sky subscribe bskyb subscription package get sky included extra charge customers subscribe bskybs channels still pay monthly fee enable sky functions january bskyb discontinued sky box limited standard sky box multiroom upgrade started issue skyhd box standard thus giving new subscribers functions sky february bskyb discontinued nonhd variant multiroom box offering smaller version skyhd box without sky functionality september sky launched new tv advertising campaign targeting sky women march sky sky users',
#   'question': 'replaced skyhd box',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '57094d489928a8140047150a',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'name tv scrambling system bskyb uses',
#   'answer_text': 'VideoGuard',
#   'answer_start': 19,
#   'is_impossible': False},
#  {'id': '57094d489928a8140047150b',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'videoguard owned',
#   'answer_text': 'NDS',
#   'answer_start': 64,
#   'is_impossible': False},
#  {'id': '57094d489928a8140047150c',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'parent company nds',
#   'answer_text': 'Cisco Systems',
#   'answer_start': 71,
#   'is_impossible': False},
#  {'id': '57094d489928a8140047150d',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'design authority digital satellite receivers capable using service',
#   'answer_text': 'BSkyB',
#   'answer_start': 229,
#   'is_impossible': False},
#  {'id': '57094d489928a8140047150e',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'name brand personal video recorder bskyb offers',
#   'answer_text': 'Sky+',
#   'answer_start': 539,
#   'is_impossible': False},
#  {'id': '5a2c3a5cbfd06b001a5aea79',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'name tv scrambling system bskyb couldnt use',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c3a5cbfd06b001a5aea7a',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'whose digital receivers built one manufacturer',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c3a5cbfd06b001a5aea7b',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'available standalone dvb cams',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c3a5cbfd06b001a5aea7c',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'company never involved nds',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '5a2c3a5cbfd06b001a5aea7d',
#   'context': 'bskyb utilises videoguard paytv scrambling system owned nds cisco systems company tight controls use videoguard decoders available standalone dvb cams conditionalaccess modules bskyb design authority digital satellite receivers capable receiving service receivers though designed built different manufacturers must conform user interface lookandfeel others extends personal video recorder pvr offering branded sky',
#   'question': 'name brand video recorder bskyb never sold',
#   'answer_text': '',
#   'answer_start': -1,
#   'is_impossible': True},
#  {'id': '570953a7efce8f15003a7dfe',
#   'context': 'bskyb virgin media became involved dispute carriage sky channels cable tv failure renew existing carriage agreements negotiated ntl telewest resulted virgin media removing basic channels network march virgin media claimed bskyb substantially increased asking price channels claim bskyb denied basis new deal offered substantially value including hd channels video demand content previously carried cable',
#   'question': 'year bskyb virgin media dispute carriage sky channels cable tv',
#   'answer_text': '2007',
#   'answer_start': 3,
#   'is_impossible': False},
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(processed_train_data)

# %%
df.head()
# Out:
#                          id  \
# 0  56ddde6b9a695914005b9628
# 1  56ddde6b9a695914005b9629
# 2  56ddde6b9a695914005b962a
# 3  56ddde6b9a695914005b962b
# 4  56ddde6b9a695914005b962c
#
#                                              context  \
# 0  normans norman nourmands french normands latin...
# 1  normans norman nourmands french normands latin...
# 2  normans norman nourmands french normands latin...
# 3  normans norman nourmands french normands latin...
# 4  normans norman nourmands french normands latin...
#
#                                        question                  answer_text  \
# 0                      country normandy located                       France
# 1                              normans normandy      10th and 11th centuries
# 2                     countries norse originate  Denmark, Iceland and Norway
# 3                                  norse leader                        Rollo
# 4  century normans first gain separate identity                 10th century
#
#    answer_start  is_impossible
# 0           159          False
# 1            94          False
# 2           256          False
# 3           308          False
# 4           671          False

# %%
df.to_csv("dev-v2.0.csv", index=False)
